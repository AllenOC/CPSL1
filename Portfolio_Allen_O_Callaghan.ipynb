# %% [markdown]
# <a href="https://colab.research.google.com/github/AllenOC/CPSL1/blob/master/Portfolio_Allen_O_Callaghan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split


# Read the CSV file.
data = pd.read_csv("https://raw.githubusercontent.com/kvinlazy/Dataset/master/cars_clus.csv")

# Select the relevant numerical columns.
     #column nakmes: manufact,model,sales,resale,type,price,engine_s,horsepow,wheelbas,width,length,curb_wgt,fuel_cap,mpg,lnsales,partition
selected_cols = ['sales','resale', 'engine_s','horsepow', 'wheelbas','width','length', 'curb_wgt','fuel_cap', 'mpg', 'lnsales', 'price']
print(data.columns)

data = data[selected_cols].dropna()

# Shuffle the dataset.
data_shuffled = data.sample(frac=1.0, random_state=0)

# Split into input part X and output part Y.
X = data_shuffled.drop('price', axis=1)

# Map the diagnosis code to a human-readable label.
def to_label(y):
    return [None, 'normal', 'suspect', 'pathologic'][(int(y))]

Y = data_shuffled['price']#.apply(to_label)


# Partition the data into training and test sets.
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2, random_state=0)

Y.head()
X.head()
data.head()
# Out:
# Index(['manufact', 'model', 'sales', 'resale', 'type', 'price', 'engine_s',
#        'horsepow', 'wheelbas', 'width', 'length', 'curb_wgt', 'fuel_cap',
#        'mpg', 'lnsales', 'partition'],
#       dtype='object')
#     sales  resale engine_s horsepow wheelbas   width   length curb_wgt  \
# 0  16.919  16.360    1.800  140.000  101.200  67.300  172.400    2.639
# 1  39.384  19.875    3.200  225.000  108.100  70.300  192.900    3.517
# 2  14.114  18.225    3.200  225.000  106.900  70.600  192.000    3.470
# 3   8.588  29.725    3.500  210.000  114.600  71.400  196.600    3.850
# 4  20.397  22.255    1.800  150.000  102.600  68.200  178.000    2.998
#
#   fuel_cap     mpg lnsales   price
# 0   13.200  28.000   2.828  21.500
# 1   17.200  25.000   3.673  28.400
# 2   17.200  26.000   2.647  $null$
# 3   18.000  22.000   2.150  42.000
# 4   16.400  27.000   3.015  23.990
